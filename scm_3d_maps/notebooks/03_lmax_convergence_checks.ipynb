# %% [markdown]
# # 03_lmax_convergence_checks.ipynb
# Run this notebook from the repository root or with the repository root as current working directory.

# %%
from scm_3d_maps.scm3d_convergence import run_lmax_convergence_checks
run_lmax_convergence_checks()
